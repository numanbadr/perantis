# %% [markdown]
# ## ASSIGNMENT
#
# 1. Use pytorch to model class face recognition using master_dataset.npz

# %%
import torch 
from torch import nn 
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor, Lambda, Compose
import matplotlib.pyplot as plt
import numpy as np
import torchvision
from sklearn.model_selection import train_test_split
import random

# %%
# Load the data 

dataSet = 'master_dataset.npz'
with np.load(dataSet, allow_pickle=True) as data:
    dataImages = data['images']
    dataLabels = data['labels'].astype('int64')
    dataLabelNames = data['labelnames']

# %%
# Convert size 

import cv2 as cv 


N = len(dataImages)
shape = (N, 200, 200, 3)
y = np.empty(shape)

for i in range(N):
    y[i] = cv.resize(dataImages[i], [200,200], interpolation=cv.INTER_NEAREST)

dataImages = y
print(dataImages.dtype, y.dtype, y.shape)
# Out:
# float64 float64 (423, 200, 200, 3)

# %%
# Normalize

dataImages = dataImages / 255.0

# %%
dataImages.dtype
# Out:
# dtype('float64')

# %%
# Transform into torch

dataImages2 = torch.Tensor(dataImages)

# %%
# Convert to tuple

all_data = []
for i in range(len(dataImages2)):
   all_data.append([dataImages2[i], dataLabels[i]])

random.shuffle(all_data)

# %%
# Split data into training and testing - based on tuple

train_size = int(0.75 * len(all_data))
test_size = len(all_data) - train_size
train_dataset, test_dataset, = torch.utils.data.random_split(all_data, [train_size, test_size])

# %%
# Check the size of train_dataset and test_dataset

len(train_dataset), len(test_dataset)
# Out:
# (317, 106)

# %%
classes = {
    0: "afiq",
    1: "azureen",
    2: "gavin",
    3: "goke",
    4: "inamul",
    5: "jincheng",
    6: "mahmuda",
    7: "numan",
    8: "saseendran"
}

# %%
X, y = train_dataset[0]
print(X.shape)
print(X.squeeze().shape)
print(y)
# Out:
# torch.Size([200, 200, 3])
# torch.Size([200, 200, 3])
# 3

# %%
# Display
img = X.squeeze()
plt.imshow(img, cmap="gray")
plt.title(f"{y}: {classes[y]}")
plt.show()

# %%
# Display in loop 

for i in range (2,5):

    X, y = train_dataset[i]
    print(X.shape)
    print(X.squeeze().shape)
    print(y)

    img = X.squeeze()
    plt.imshow(img, cmap="gray")
    plt.title(f"{y}: {classes[y]}")
    plt.show()
# Out:
# torch.Size([200, 200, 3])
# torch.Size([200, 200, 3])
# 1
# torch.Size([200, 200, 3])
# torch.Size([200, 200, 3])
# 5
# torch.Size([200, 200, 3])
# torch.Size([200, 200, 3])
# 3

# %%
batch_size = 20

# Create data loaders.
train_dataloader = DataLoader(train_dataset, batch_size=batch_size)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size)

for X, y in test_dataloader:
    print("Shape of X [N, C, H, W]: ", X.shape)
    print("Shape of y: ", y.shape, y.dtype)
    break
# Out:
# Shape of X [N, C, H, W]:  torch.Size([20, 200, 200, 3])
# Shape of y:  torch.Size([20]) torch.int64

# %%
import torch

# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")

input_features = 3*200*200
# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(input_features, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 9)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)
# Out:
# Using cuda device
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=120000, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=512, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=512, out_features=9, bias=True)
#   )
# )

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    return loss, current

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    
    return test_loss, correct

# %%
epochs = 30
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.196801  [    0/  317]
# Test Error:
#  Accuracy: 17.0%, Avg loss: 2.167905
#
# Epoch 2
# -------------------------------
# loss: 2.167957  [    0/  317]
# Test Error:
#  Accuracy: 22.6%, Avg loss: 2.147534
#
# Epoch 3
# -------------------------------
# loss: 2.146481  [    0/  317]
# Test Error:
#  Accuracy: 24.5%, Avg loss: 2.124449
#
# Epoch 4
# -------------------------------
# loss: 2.123772  [    0/  317]
# Test Error:
#  Accuracy: 29.2%, Avg loss: 2.100884
#
# Epoch 5
# -------------------------------
# loss: 2.100086  [    0/  317]
# Test Error:
#  Accuracy: 30.2%, Avg loss: 2.076656
#
# Epoch 6
# -------------------------------
# loss: 2.075489  [    0/  317]
# Test Error:
#  Accuracy: 31.1%, Avg loss: 2.051216
#
# Epoch 7
# -------------------------------
# loss: 2.049513  [    0/  317]
# Test Error:
#  Accuracy: 34.0%, Avg loss: 2.024545
#
# Epoch 8
# -------------------------------
# loss: 2.021757  [    0/  317]
# Test Error:
#  Accuracy: 35.8%, Avg loss: 1.996267
#
# Epoch 9
# -------------------------------
# loss: 1.991837  [    0/  317]
# Test Error:
#  Accuracy: 35.8%, Avg loss: 1.966502
#
# Epoch 10
# -------------------------------
# loss: 1.960342  [    0/  317]
# Test Error:
#  Accuracy: 37.7%, Avg loss: 1.935388
#
# Epoch 11
# -------------------------------
# loss: 1.927139  [    0/  317]
# Test Error:
#  Accuracy: 38.7%, Avg loss: 1.903171
#
# Epoch 12
# -------------------------------
# loss: 1.892708  [    0/  317]
# Test Error:
#  Accuracy: 42.5%, Avg loss: 1.869913
#
# Epoch 13
# -------------------------------
# loss: 1.857147  [    0/  317]
# Test Error:
#  Accuracy: 45.3%, Avg loss: 1.835926
#
# Epoch 14
# -------------------------------
# loss: 1.820609  [    0/  317]
# Test Error:
#  Accuracy: 46.2%, Avg loss: 1.801416
#
# Epoch 15
# -------------------------------
# loss: 1.783421  [    0/  317]
# Test Error:
#  Accuracy: 50.0%, Avg loss: 1.765773
#
# Epoch 16
# -------------------------------
# loss: 1.745146  [    0/  317]
# Test Error:
#  Accuracy: 52.8%, Avg loss: 1.729591
#
# Epoch 17
# -------------------------------
# loss: 1.706169  [    0/  317]
# Test Error:
#  Accuracy: 55.7%, Avg loss: 1.692839
#
# Epoch 18
# -------------------------------
# loss: 1.666153  [    0/  317]
# Test Error:
#  Accuracy: 57.5%, Avg loss: 1.655363
#
# Epoch 19
# -------------------------------
# loss: 1.625201  [    0/  317]
# Test Error:
#  Accuracy: 58.5%, Avg loss: 1.617147
#
# Epoch 20
# -------------------------------
# loss: 1.583270  [    0/  317]
# Test Error:
#  Accuracy: 63.2%, Avg loss: 1.578265
#
# Epoch 21
# -------------------------------
# loss: 1.540375  [    0/  317]
# Test Error:
#  Accuracy: 67.9%, Avg loss: 1.538767
#
# Epoch 22
# -------------------------------
# loss: 1.496685  [    0/  317]
# Test Error:
#  Accuracy: 70.8%, Avg loss: 1.498967
#
# Epoch 23
# -------------------------------
# loss: 1.451899  [    0/  317]
# Test Error:
#  Accuracy: 71.7%, Avg loss: 1.458593
#
# Epoch 24
# -------------------------------
# loss: 1.406316  [    0/  317]
# Test Error:
#  Accuracy: 71.7%, Avg loss: 1.417897
#
# Epoch 25
# -------------------------------
# loss: 1.359885  [    0/  317]
# Test Error:
#  Accuracy: 74.5%, Avg loss: 1.376690
#
# Epoch 26
# -------------------------------
# loss: 1.312994  [    0/  317]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 1.335316
#
# Epoch 27
# -------------------------------
# loss: 1.265653  [    0/  317]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 1.293949
#
# Epoch 28
# -------------------------------
# loss: 1.218116  [    0/  317]
# Test Error:
#  Accuracy: 79.2%, Avg loss: 1.253056
#
# Epoch 29
# -------------------------------
# loss: 1.170873  [    0/  317]
# Test Error:
#  Accuracy: 81.1%, Avg loss: 1.212776
#
# Epoch 30
# -------------------------------
# loss: 1.124252  [    0/  317]
# Test Error:
#  Accuracy: 84.9%, Avg loss: 1.173217
#
# Done!

# %%
torch.save(model.state_dict(), "model_2.pth")
print("Saved PyTorch Model State to model.pth")
# Out:
# Saved PyTorch Model State to model.pth

# %%
model = NeuralNetwork()
model.load_state_dict(torch.load("model_2.pth"))
# Out:
# <All keys matched successfully>

# %%
model.eval()
x, y = test_dataset[0][0], test_dataset[0][1]
x = x.view(1, -1)
with torch.no_grad():
    pred = model(x)
    predicted, actual = classes[pred[0].argmax(0).item()], classes[y]
    print(f'Predicted: "{predicted}", Actual: "{actual}"')
# Out:
# Predicted: "afiq", Actual: "afiq"

# %%
pred[0]
# Out:
# tensor([ 1.1716,  0.1331,  0.0754, -0.0896, -1.2706, -0.3527,  0.1903,  0.3047,
#          0.3260])

# %%
model.eval()
x, y = test_dataset[1][0], test_dataset[1][1]
x = x.view(1, -1)
with torch.no_grad():
    pred = model(x)
    predicted, actual = classes[pred[0].argmax(0).item()], classes[y]
    print(f'Predicted: "{predicted}", Actual: "{actual}"')
# Out:
# Predicted: "goke", Actual: "goke"

# %%
pred[0]
# Out:
# tensor([ 0.1759,  0.2884,  0.6211,  2.8611, -2.8770, -1.2456,  0.2020,  0.3648,
#          0.1273])

# %%
i = 40
model.eval()
x, y = test_dataset[i][0], test_dataset[i][1]
x = x.view(1, -1)
with torch.no_grad():
    pred = model(x)
    predicted, actual = classes[pred[0].argmax(0).item()], classes[y]
    print(f'Predicted: "{predicted}", Actual: "{actual}"')
# Out:
# Predicted: "goke", Actual: "goke"

# %%
# Run cell class NeuralNetwork
# Run cell loss_fn & optimizer
# Run cell def test
# Run cell def train
# Pastu skip yang lain & terus run yg ni

import os

maxIterations = 5
thresholdAcc = 0.0

testLoss = 0.0
testAcc = 0.0
epochs = 30

for iter in range(maxIterations):

    print(f'Simulation {iter+1}/{maxIterations}', end='... ')

    for t in range(epochs):
        train(train_dataloader, model, loss_fn, optimizer)
        test_loss, testAcc = test(test_dataloader, model, loss_fn)

    # Save model if greater than threshold-accuracy 0.95
    if testAcc > thresholdAcc:
        torch.save(model.state_dict(), "model_max.pth")
        print("Saved PyTorch Model State to model_max.pth")
        thresholdAcc = testAcc

print('Highest Acc =', thresholdAcc)
print('All task is done.')
# Out:
# Simulation 1/5... loss: 0.039835  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.205082
#
# loss: 0.039299  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.204712
#
# loss: 0.038780  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.204276
#
# loss: 0.038267  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.203847
#
# loss: 0.037752  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.203550
#
# loss: 0.037238  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.203166
#
# loss: 0.036783  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.202782
#
# loss: 0.036297  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.202400
#
# loss: 0.035833  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.202089
#
# loss: 0.035381  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.201684
#
# loss: 0.034936  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.201380
#
# loss: 0.034491  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.201089
#
# loss: 0.034040  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.200767
#
# loss: 0.033655  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.200434
#
# loss: 0.033227  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.200155
#
# loss: 0.032810  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.199835
#
# loss: 0.032381  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.199544
#
# loss: 0.032021  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.199311
#
# loss: 0.031632  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.198997
#
# loss: 0.031242  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.198704
#
# loss: 0.030875  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.198457
#
# loss: 0.030495  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.198232
#
# loss: 0.030139  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.197989
#
# loss: 0.029767  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.197734
#
# loss: 0.029426  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.197490
#
# loss: 0.029079  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.197307
#
# loss: 0.028747  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.197034
#
# loss: 0.028430  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.196807
#
# loss: 0.028099  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.196628
#
# loss: 0.027758  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.196416
#
# Saved PyTorch Model State to model_max.pth
# Simulation 2/5... loss: 0.027458  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.196219
#
# loss: 0.027153  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.196072
#
# loss: 0.026836  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.195832
#
# loss: 0.026552  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.195674
#
# loss: 0.026245  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.195478
#
# loss: 0.025956  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.195310
#
# loss: 0.025685  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.195152
#
# loss: 0.025392  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.194975
#
# loss: 0.025127  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.194814
#
# loss: 0.024861  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.194672
#
# loss: 0.024585  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.194485
#
# loss: 0.024334  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.194328
#
# loss: 0.024082  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.194247
#
# loss: 0.023838  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.194065
#
# loss: 0.023570  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.193922
#
# loss: 0.023335  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.193781
#
# loss: 0.023092  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.193665
#
# loss: 0.022846  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.193513
#
# loss: 0.022632  [    0/  317]
# Test Error:
#  Accuracy: 94.3%, Avg loss: 0.193413
#
# loss: 0.022385  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.193253
#
# loss: 0.022171  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.193138
#
# loss: 0.021932  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.193023
#
# loss: 0.021723  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.192887
#
# loss: 0.021493  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.192811
#
# loss: 0.021302  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.192665
#
# loss: 0.021076  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.192557
#
# loss: 0.020872  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.192471
#
# loss: 0.020666  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.192383
#
# loss: 0.020466  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.192224
#
# loss: 0.020274  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.192186
#
# Saved PyTorch Model State to model_max.pth
# Simulation 3/5... loss: 0.020066  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.192057
#
# loss: 0.019886  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.191958
#
# loss: 0.019691  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.191893
#
# loss: 0.019506  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.191761
#
# loss: 0.019315  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.191686
#
# loss: 0.019147  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.191637
#
# loss: 0.018951  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.191477
#
# loss: 0.018794  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.191453
#
# loss: 0.018601  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.191335
#
# loss: 0.018446  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.191313
#
# loss: 0.018265  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.191215
#
# loss: 0.018105  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.191105
#
# loss: 0.017930  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.191066
#
# loss: 0.017778  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.191015
#
# loss: 0.017605  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.190943
#
# loss: 0.017446  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.190853
#
# loss: 0.017290  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.190833
#
# loss: 0.017134  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.190716
#
# loss: 0.016981  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.190651
#
# loss: 0.016837  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.190580
#
# loss: 0.016681  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.190501
#
# loss: 0.016536  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.190442
#
# loss: 0.016393  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.190389
#
# loss: 0.016247  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.190316
#
# loss: 0.016109  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.190250
#
# loss: 0.015968  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.190235
#
# loss: 0.015834  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.190182
#
# loss: 0.015693  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.190088
#
# loss: 0.015569  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.190075
#
# loss: 0.015425  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189980
#
# Simulation 4/5... loss: 0.015307  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189976
#
# loss: 0.015165  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189924
#
# loss: 0.015044  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189861
#
# loss: 0.014919  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189830
#
# loss: 0.014803  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189756
#
# loss: 0.014671  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189736
#
# loss: 0.014561  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189698
#
# loss: 0.014439  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189625
#
# loss: 0.014325  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189607
#
# loss: 0.014202  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189552
#
# loss: 0.014095  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189515
#
# loss: 0.013976  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189437
#
# loss: 0.013866  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189434
#
# loss: 0.013759  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189373
#
# loss: 0.013645  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189322
#
# loss: 0.013545  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189282
#
# loss: 0.013438  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189265
#
# loss: 0.013331  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189225
#
# loss: 0.013229  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189199
#
# loss: 0.013122  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189151
#
# loss: 0.013027  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189163
#
# loss: 0.012923  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189121
#
# loss: 0.012824  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189129
#
# loss: 0.012725  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189049
#
# loss: 0.012625  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.189065
#
# loss: 0.012536  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188996
#
# loss: 0.012435  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188991
#
# loss: 0.012348  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188960
#
# loss: 0.012256  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188935
#
# loss: 0.012158  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188953
#
# Simulation 5/5... loss: 0.012075  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188910
#
# loss: 0.011982  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188912
#
# loss: 0.011894  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188869
#
# loss: 0.011808  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188840
#
# loss: 0.011718  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188817
#
# loss: 0.011637  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188851
#
# loss: 0.011557  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188804
#
# loss: 0.011470  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188797
#
# loss: 0.011387  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188762
#
# loss: 0.011306  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188749
#
# loss: 0.011225  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188751
#
# loss: 0.011142  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188755
#
# loss: 0.011068  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188710
#
# loss: 0.010981  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188685
#
# loss: 0.010917  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188677
#
# loss: 0.010827  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188736
#
# loss: 0.010760  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188663
#
# loss: 0.010675  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188630
#
# loss: 0.010611  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188658
#
# loss: 0.010528  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188621
#
# loss: 0.010462  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188629
#
# loss: 0.010384  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188617
#
# loss: 0.010317  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188592
#
# loss: 0.010244  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188583
#
# loss: 0.010179  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188594
#
# loss: 0.010105  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188583
#
# loss: 0.010039  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188565
#
# loss: 0.009969  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188555
#
# loss: 0.009906  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188528
#
# loss: 0.009835  [    0/  317]
# Test Error:
#  Accuracy: 95.3%, Avg loss: 0.188527
#
# Highest Acc = 0.9528301886792453
# All task is done.
